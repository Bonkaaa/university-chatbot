# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(
    columns=[
        "No.", 
        "faithfulness", 
        "answer_relevancy", 
        "context_precision",
        "context_recall",
    ]
)

df
# Out:
# Empty DataFrame
# Columns: [No., faithfulness, answer_relevancy, context_precision, context_recall]
# Index: []

# %%
df.loc[len(df)] = [0, 0.3750, 0.7313, 0.3095, 1.0000] # Record 1/1 [cite: 2, 3]
df.loc[len(df)] = [1, 0.8571, 0.8357, 1.0000, 1.0000] # Record 1/9 [cite: 4, 5]
df.loc[len(df)] = [2, 0.7500, 0.7632, 1.0000, 1.0000] # Record 2/9 [cite: 6, 7]
df.loc[len(df)] = [3, 1.0000, 0.8729, 0.0000, 0.0000] # Record 3/9 [cite: 8, 9]
df.loc[len(df)] = [4, 0.4000, 0.5506, 0.8167, 1.0000] # Record 4/9 [cite: 10, 11]
df.loc[len(df)] = [5, 0.7500, 0.7592, 1.0000, 1.0000] # Record 5/9 [cite: 12, 13]
df.loc[len(df)] = [6, 0.1250, 0.8700, 0.0000, 0.0000] # Record 6/9 [cite: 14, 15]
df.loc[len(df)] = [7, 0.5000, 0.8205, 0.1667, 1.0000] # Record 7/9 [cite: 16, 17]
df.loc[len(df)] = [8, 0.6364, 0.9318, 0.1667, 1.0000] # Record 8/9 [cite: 18, 19]
df.loc[len(df)] = [9, 0.7143, np.nan, 0.1667, 1.0000] # Record 9/9 

df.loc[len(df)] = [10, 0.4286, 0.8253, 0.0000, 0.0000] # Record 1/10 [cite: 22, 23]
df.loc[len(df)] = [11, 0.5556, 0.7804, 0.0000, 0.0000] # Record 2/10 [cite: 24, 25]
df.loc[len(df)] = [12, 0.9000, 0.8897, 0.6429, 0.0000] # Record 3/10 [cite: 26, 27]
df.loc[len(df)] = [13, 0.5714, 0.8756, 0.0000, 0.0000] # Record 4/10 [cite: 28, 29]
df.loc[len(df)] = [14, 0.6250, 0.9282, 0.1944, 1.0000] # Record 5/10 [cite: 30, 31]
df.loc[len(df)] = [15, 0.7143, 0.6172, 0.6429, 1.0000] # Record 6/10 [cite: 32, 33]
df.loc[len(df)] = [16, 0.0000, 0.8905, 0.4167, 1.0000] # Record 7/10 [cite: 34, 35]
df.loc[len(df)] = [17, 0.6000, 0.9332, 0.1111, 1.0000] # Record 8/10 [cite: 36, 37]
df.loc[len(df)] = [18, 0.6667, 0.9258, 1.0000, 1.0000] # Record 9/10 [cite: 38, 39]
df.loc[len(df)] = [19, 0.3333, 0.8330, np.nan, 1.0000] # Record 10/10 

df.loc[len(df)] = [20, 0.4000, 0.8445, 0.1667, 1.0000] # Record 1/10 [cite: 42, 43]
df.loc[len(df)] = [21, 1.0000, 0.7012, 0.8333, 1.0000] # Record 2/10 [cite: 44, 45]
df.loc[len(df)] = [22, 0.8000, 0.8284, 0.1667, 1.0000] # Record 3/10 [cite: 46, 47]
df.loc[len(df)] = [23, 1.0000, 0.0000, 1.0000, 0.5000] # Record 4/10 [cite: 48, 49]
df.loc[len(df)] = [24, 0.4444, 0.8106, 0.0000, 0.0000] # Record 5/10 [cite: 50, 51]
df.loc[len(df)] = [25, 0.7143, 0.9379, 0.3095, 1.0000] # Record 6/10 [cite: 52, 53]
df.loc[len(df)] = [26, 0.6000, 0.9509, 0.3333, 1.0000] # Record 7/10 [cite: 54, 55]
df.loc[len(df)] = [27, 0.5000, 0.8226, 0.6667, 1.0000] # Record 8/10 [cite: 56, 57]
df.loc[len(df)] = [28, 0.2000, 0.8952, 1.0000, 1.0000] # Record 9/10 [cite: 58, 59]
df.loc[len(df)] = [29, 0.4000, 0.8081, 0.1667, 1.0000] # Record 10/10 [cite: 60, 61]

# %%
df["No."] = df["No."].astype(int)
df[['faithfulness', 'answer_relevancy', 'context_precision', 'context_recall']] = df[['faithfulness', 'answer_relevancy', 'context_precision', 'context_recall']].astype(float)

# %%
df.head()
# Out:
#    No.  faithfulness  answer_relevancy  context_precision  context_recall
# 0    0        0.3750            0.7313             0.3095             1.0
# 1    1        0.8571            0.8357             1.0000             1.0
# 2    2        0.7500            0.7632             1.0000             1.0
# 3    3        1.0000            0.8729             0.0000             0.0
# 4    4        0.4000            0.5506             0.8167             1.0

# %%
df_avg = df.mean(numeric_only=True)
print(df_avg)
# Out:
# No.                  14.500000
# faithfulness          0.585380
# answer_relevancy      0.801155
# context_precision     0.423352
# context_recall        0.750000
# dtype: float64
